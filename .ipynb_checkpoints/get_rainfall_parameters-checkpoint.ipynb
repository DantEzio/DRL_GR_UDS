# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # RSH 降雨参数
# ## 参数顺序 A, C, P, b, n, r

# %%
re=np.load('./RSH/Parameter_east.npy')
rw=np.load('./RSH/Parameter_west.npy')

# %%
re
# Out:
# array([[30.  ,  1.18,  1.  , 18.  ,  0.91,  0.5 ],
#        [20.  ,  1.15,  1.  , 16.  ,  0.91,  0.5 ],
#        [25.  ,  1.11,  1.  , 21.  ,  0.86,  0.5 ],
#        [30.  ,  1.16,  3.  , 18.  ,  0.89,  0.5 ],
#        [20.  ,  1.04,  3.  , 18.  ,  0.87,  0.5 ],
#        [25.  ,  1.18,  3.  , 19.  ,  0.92,  0.5 ],
#        [30.  ,  1.01,  5.  , 21.  ,  0.9 ,  0.5 ],
#        [20.  ,  1.15,  5.  , 16.  ,  0.86,  0.5 ],
#        [25.  ,  1.16,  5.  , 19.  ,  0.91,  0.5 ]])

# %%
rw
# Out:
# array([[20.  ,  1.15,  1.  , 18.  ,  0.87,  0.5 ],
#        [30.  ,  1.16,  1.  , 16.  ,  0.92,  0.5 ],
#        [25.  ,  1.18,  1.  , 18.  ,  0.86,  0.5 ],
#        [20.  ,  1.02,  3.  , 19.  ,  0.92,  0.5 ],
#        [30.  ,  0.94,  3.  , 17.  ,  0.87,  0.5 ],
#        [25.  ,  1.12,  3.  , 19.  ,  0.94,  0.5 ],
#        [20.  ,  1.08,  5.  , 19.  ,  0.91,  0.5 ],
#        [30.  ,  0.94,  5.  , 17.  ,  0.87,  0.5 ],
#        [25.  ,  1.01,  5.  , 21.  ,  0.95,  0.5 ]])

# %%
d=np.load('0.npy',allow_pickle=True).tolist()

# %%
d.keys()
# Out:
# dict_keys(['time', 'state', 'action', 'reward', 'F', 'C'])

# %%
plt.plot(d['state'])
