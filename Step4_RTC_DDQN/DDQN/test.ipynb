# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import swmm_api

# %%
data=np.load('./Results/RSH/0.npy',allow_pickle=True).tolist()
plt.plot(np.array(data['F'])+np.array(data['C']),label='DDQN')
data=np.load('./PPO Results/RSH/0.npy',allow_pickle=True).tolist()
plt.plot(np.array(data['F'])+np.array(data['C']),label='PPO')
plt.legend()

# %%
data=np.load('./PPO Results/RSH/0.npy',allow_pickle=True).tolist()
plt.plot(data['action'])

# %%
# Out:
# [30, 30, 30, 30, 128]

# %%
np.random.randint(0,128,100).reshape(-1,1)
# Out:
# array([[ 27],
#        [  6],
#        [ 69],
#        [123],
#        [ 24],
#        [  5],
#        [  9],
#        [ 63],
#        [ 17],
#        [  2],
#        [ 95],
#        [ 79],
#        [108],
#        [ 25],
#        [ 42],
#        [ 46],
#        [ 84],
#        [ 45],
#        [ 77],
#        [  6],
#        [114],
#        [125],
#        [ 88],
#        [ 44],
#        [  5],
#        [ 45],
#        [121],
#        [ 66],
#        [ 69],
#        [ 71],
#        [  9],
#        [116],
#        [ 46],
#        [ 90],
#        [ 68],
#        [ 46],
#        [104],
#        [ 83],
#        [ 51],
#        [ 35],
#        [ 31],
#        [  5],
#        [ 44],
#        [ 48],
#        [ 55],
#        [ 20],
#        [ 17],
#        [ 19],
#        [109],
#        [ 45],
#        [ 73],
#        [  2],
#        [116],
#        [ 99],
#        [ 54],
#        [ 65],
#        [ 32],
#        [ 12],
#        [ 96],
#        [ 68],
#        [ 34],
#        [ 33],
# ...
